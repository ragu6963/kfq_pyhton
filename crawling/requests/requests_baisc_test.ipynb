# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
print(r)
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '[{"id":"12917651210","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":276985523,"name":"tflem/real-prairie-delights","url":"https://api.github.com/repos/tflem/real-prairie-delights"},"payload":{"action":"opened","number":3,"pull_request":{"url":"https://api.github.com/repos/tflem/real-prairie-delights/pulls/3","id":449813249,"node_id":"MDExOlB1bGxSZXF1ZXN0NDQ5ODEzMjQ5","html_url":"https://github.com/tflem/real-prairie-delights/pull/3","diff_url":"https://github.com/tflem/real-prairie-delights/pull/3.diff","patch_url":"https://github.com/tflem/real-prairie-delights/pull/3.patch","issue_url":"https://api.github.com/repos/tflem/real-prairie-delights/issues/3","number":3,"state":"open","locked":false,"title":"Bump lodash from 4.17.15 to 4.17.19","user":{"login":"dependabot[bot]","id":49
# ...

# %%
r= requests.get("https://www.naver.com")

# %%
r.text
# Out:
# '\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양
# ...

# %%
payload ={'key1':'value1','key2':'value2'}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
r.text
# Out:
# '{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0f9f3c-74c6d20ba6b768bbd527eed6"\n  }, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2"\n}\n'

# %%
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2'

# %%
r= requests.get("http://127.0.0.1:8089/")

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<!doctype html>\n<html lang="en">\n\n<head>\n  <!-- Required meta tags -->\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\n  <!-- Bootstrap CSS -->\n  <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css">\n  <title>home 화면 </title>\n  \n  \n</head>\n\n<body>\n  <nav class="navbar navbar-dark bg-dark">\n    <a class="navbar-brand" href="/">\n        <img src="/static/swimming.png" width="30" height="30" class="d-inline-block align-top" alt="">\n        Bootstrap\n    </a>\n    <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNavDropdown"\n        aria-controls="navbarNavDropdown" aria-expanded="false" aria-label="Toggle navigation">\n        <span class="navbar-toggler-icon"></span>\n    </button>\n    <div class="collapse navbar-collapse" id="navbarNavDropdown">\n        <ul class="navbar-nav">\n            <li class="nav-ite
# ...

# %%
r.url
# Out:
# 'http://127.0.0.1:8089/'

# %%
data = {'sm':'top_hty','fbm':1,'ie':'utf8','qeury':'%EB%8C%80%EA%B5%AC'}

# %%
r = requests.get('https://search.naver.com/search.naver', data = data)

# %%
r.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content=" : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'\'의 네이버 통합검색 결과입니다."> <title> : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200528.css"> <link rel="stylesheet" type="text/css" href="https://
# ...

# %%
payload_tuples = [('key1', 'value1'), ('key1', 'value2')]

# %%
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)

# %%
r1.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": [\n      "value1", \n      "value2"\n    ]\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0fa351-07541a2885cc9c40c7826e90"\n  }, \n  "json": null, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
r1.url
# Out:
# 'https://httpbin.org/post'

# %%
import json

# %%
r = requests.get('https://api.github.com/events')

# %%
j= r.json()

# %%
j[0]
# Out:
# {'id': '12917791082',
#  'type': 'PushEvent',
#  'actor': {'id': 5107025,
#   'login': 'dillonfagan',
#   'display_login': 'dillonfagan',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dillonfagan',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/5107025?'},
#  'repo': {'id': 278711645,
#   'name': 'dillonfagan/liberty',
#   'url': 'https://api.github.com/repos/dillonfagan/liberty'},
#  'payload': {'push_id': 5380912402,
#   'size': 1,
#   'distinct_size': 1,
#   'ref': 'refs/heads/master',
#   'head': 'cec4a89bbbb7525dca3a28f429f62985f123d844',
#   'before': 'fc2279197ca6e145f13bf933b02836108f8e290d',
#   'commits': [{'sha': 'cec4a89bbbb7525dca3a28f429f62985f123d844',
#     'author': {'email': 'dillonfagan@pm.me', 'name': 'Dillon Fagan'},
#     'message': 'Run rust installer with defaults',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/dillonfagan/liberty/commits/cec4a89bbbb7525dca3a28f429f62985f123d844'}]},
#  'public': True,
# ...

# %%
url = 'https://api.github.com/some/endpoint'

# %%
headers = {'user-agent': 'my-app/0.0.1'}

# %%
r = requests.get(url, headers=headers)

# %%
r
# Out:
# <Response [404]>

# %%
r.headers
# Out:
# {'date': 'Thu, 16 Jul 2020 01:14:25 GMT', 'content-type': 'application/json; charset=utf-8', 'server': 'GitHub.com', 'status': '404 Not Found', 'x-github-media-type': 'github.v3; format=json', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'access-control-allow-origin': '*', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'x-frame-options': 'deny', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'content-security-policy': "default-src 'none'", 'vary': 'Accept-Encoding, Accept, X-Requested-With', 'content-encoding': 'gzip', 'X-Ratelimit-Limit': '60', 'X-Ratelimit-Remaining': '22', 'X-Ratelimit-Reset': '1594864933', 'Content-Length': '96', 'X-GitHub-Request-I
# ...

# %%
data = {'userid':'123'}
r = requests.post('http://127.0.0.1:8089/ajaxlist',data=data)

# %%
r.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"\n  "http://www.w3.org/TR/html4/loose.dtd">\n<html>\n  <head>\n    <title>TypeError: Object of type User is not JSON serializable // Werkzeug Debugger</title>\n    <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"\n        type="text/css">\n    <!-- We need to make sure this has a favicon so that the debugger does\n         not by accident trigger a request to /favicon.ico which might\n         change the application state. -->\n    <link rel="shortcut icon"\n        href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">\n    <script src="?__debugger__=yes&amp;cmd=resource&amp;f=jquery.js"></script>\n    <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>\n    <script type="text/javascript">\n      var TRACEBACK = 1630312063176,\n          CONSOLE_MODE = false,\n          EVALEX = true,\n          EVALEX_TRUSTED = false,\n          SECRET = "hRmgnJ9REFeW0MJ0Xyx
# ...

# %%
r.json()
# Out:
# [{'useradd': '123',
#   'userage': 1,
#   'usergender': 'male',
#   'userid': '123123',
#   'usermail': '12123@naver.com',
#   'username': 'asdsa213',
#   'userpw': '12321',
#   'usertel': '123213'}]

# %%
r.headers
# Out:
# {'Content-Type': 'application/json', 'Content-Length': '219', 'Server': 'Werkzeug/1.0.0 Python/3.7.6', 'Date': 'Thu, 16 Jul 2020 01:22:31 GMT'}

# %%
data ={'useradd': '123',
  'userage': 1,
  'usergender': 'male',
  'userid': '1231323',
  'usermail': '12123@naver.com',
  'username': 'asdsa213',
  'userpw': '12321',
  'usertel': '123213'}
r = requests.post('http://127.0.0.1:8089/usersform',data=data)

# %%
r
# Out:
# <Response [200]>

# %%
payload_tuples = [('key1', 'value1'), ('key1', 'value2')]

# %%
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)

# %%
r1
# Out:
# <Response [200]>

# %%
r1.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": [\n      "value1", \n      "value2"\n    ]\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0fae01-1cf251580c3382c6e453876c"\n  }, \n  "json": null, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
print(r1.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-5f0fae01-1cf251580c3382c6e453876c"
#   },
#   "json": null,
#   "origin": "1.221.125.150",
#   "url": "https://httpbin.org/post"
# }

# %%
payload_dict = {'key1': ['value1', 'value2']}

# %%
r2 = requests.post('https://httpbin.org/post', data=payload_dict)

# %%
print(r2.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-5f0fae4f-69ef7025e379d4a1b54fcc1b"
#   },
#   "json": null,
#   "origin": "1.221.125.150",
#   "url": "https://httpbin.org/post"
# }

# %%
r1.text == r2.text
# Out:
#   File "<ipython-input-113-6c9160208056>", line 1
#     r1.text === r2.text
#               ^
# SyntaxError: invalid syntax

# %%
[('key1', 'value1'), ('key1', 'value2')]

# %%
data =[('useradd', '123'),
  ('userage', 1),
  ('usergender', 'male'),
  ('userid', '12313sadfsadf3'),
  ('usermail', '12123@naver.com'),
  ('username', 'asdsa213'),
  ('userpw', '12321'),
  ('usertel', '123213')]
r = requests.post('http://127.0.0.1:8089/usersform',data=data)

# %%
url = 'https://api.github.com/some/endpoint'

# %%
payload = {'some': 'data'}

# %%
r = requests.post(url, data=json.dumps(payload))

# %%
r.text
# Out:
# '{"message":"Not Found","documentation_url":"https://developer.github.com/v3"}'

# %%
r
# Out:
# <Response [404]>

# %%
url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'}

r = requests.post(url, json=payload)

# %%
r
# Out:
# <Response [404]>
